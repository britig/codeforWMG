# %%
'''
Here we consider a controller trained  for the mountain-car environment in
OpenAI Gym. The controller was taken from the website.
Originally this controller is trained to be non-deterministic sampled from a
gaussian distribution, but we make it deterministic by considering the most
likely control, the mean.
'''

import tensorflow as tf
import numpy as np
import os
import gym
import time
import itertools
import sklearn.pipeline
import sklearn.preprocessing
from sklearn.kernel_approximation import RBFSampler

# Training phase
def exec_time(func):
    def new_func(*args, **kwargs):
        start = time.time()
        result = func(*args, **kwargs)
        end = time.time()
        print("Cost {} seconds.".format(end - start))
        return result

    return new_func

seed = 8902077161928034768
env = gym.envs.make("MountainCarContinuous-v0")
seed = env.seed()
video_dir = os.path.abspath("./videos")
if not os.path.exists(video_dir):
    os.makedirs(video_dir)
#env = gym.wrappers.Monitor(env, video_dir, force=True)

# Feature Preprocessing: Normalize to zero mean and unit variance
# We use a few samples from the observation space to do this
observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(observation_examples)

# Used to convert a state to a featurizes represenation.
# We use RBF kernels with different variances to cover different parts of the space
featurizer = sklearn.pipeline.FeatureUnion([
    ("rbf1", RBFSampler(gamma=5.0, n_components=100)),
    ("rbf2", RBFSampler(gamma=2.0, n_components=100)),
    ("rbf3", RBFSampler(gamma=1.0, n_components=100)),
    ("rbf4", RBFSampler(gamma=0.5, n_components=100))
])
featurizer.fit(scaler.transform(observation_examples))


def process_state(state):
    scaled = scaler.transform([state])
    featurized = featurizer.transform(scaled)
    return featurized[0]


class PolicyEstimator:
    def __init__(self, env, lamb=1e-5, learning_rate=0.01, scope="policy_estimator"):
        self.env = env
        self.lamb = lamb
        self.learning_rate = learning_rate
        self.train =True

        with tf.variable_scope(scope):
            self._build_model()
            self._build_train_op()

    def _build_model(self):
        self.state = tf.placeholder(tf.float32, [400], name="state")

        self.mu = tf.contrib.layers.fully_connected(
            inputs=tf.expand_dims(self.state, 0),
            num_outputs=1,
            activation_fn=None,
            weights_initializer=tf.contrib.layers.xavier_initializer()
        )
        self.mu = tf.squeeze(self.mu)

        self.sigma = tf.contrib.layers.fully_connected(
            inputs=tf.expand_dims(self.state, 0),
            num_outputs=1,
            activation_fn=None,
            weights_initializer=tf.contrib.layers.xavier_initializer()
        )
        self.sigma = tf.squeeze(self.sigma)
        self.sigma = tf.nn.softplus(self.sigma) + 1e-5

        self.norm_dist = tf.contrib.distributions.Normal(self.mu, self.sigma)
        self.action = self.norm_dist.sample(1)
        self.action = tf.clip_by_value(self.action, self.env.action_space.low[0],
                                       self.env.action_space.high[0])

    def _build_train_op(self):
        self.action_train = tf.placeholder(tf.float32, name="action_train")
        self.advantage_train = tf.placeholder(tf.float32, name="advantage_train")

        self.loss = -tf.log(
            self.norm_dist.prob(self.action_train) + 1e-5) * self.advantage_train \
                    - self.lamb * self.norm_dist.entropy()
        self.optimizer = tf.train.AdamOptimizer(self.learning_rate)
        self.train_op = self.optimizer.minimize(self.loss)

    def predict(self, state, sess):
        feed_dict = {self.state: process_state(state)}
        return sess.run(self.action, feed_dict=feed_dict)

    def run_deterministic(self, state, sess):
        feed_dict= {self.state:process_state(state)}
        return sess.run(self.mu, feed_dict=feed_dict)

    def update(self, state, action, advantage, sess):
        feed_dict = {
            self.state: process_state(state),
            self.action_train: action,
            self.advantage_train: advantage
        }
        sess.run([self.train_op], feed_dict=feed_dict)


class ValueEstimator:
    def __init__(self, env, learning_rate=0.01, scope="value_estimator"):
        self.env = env
        self.learning_rate = learning_rate

        with tf.variable_scope(scope):
            self._build_model()
            self._build_train_op()

    def _build_model(self):
        self.state = tf.placeholder(tf.float32, [400], name="state")

        self.value = tf.contrib.layers.fully_connected(
            inputs=tf.expand_dims(self.state, 0),
            num_outputs=1,
            activation_fn=None,
            weights_initializer=tf.contrib.layers.xavier_initializer()
        )
        self.value = tf.squeeze(self.value)

    def _build_train_op(self):
        self.target = tf.placeholder(tf.float32, name="target")
        self.loss = tf.reduce_mean(tf.squared_difference(self.value, self.target))
        self.optimizer = tf.train.AdamOptimizer(self.learning_rate)
        self.train_op = self.optimizer.minimize(self.loss)

    def predict(self, state, sess):
        return sess.run(self.value, feed_dict={self.state: process_state(state)})

    def update(self, state, target, sess):
        feed_dict = {
            self.state: process_state(state),
            self.target: target
        }
        sess.run([self.train_op], feed_dict=feed_dict)


@exec_time
def actor_critic(episodes=100, gamma=0.95, display=False, lamb=1e-5,
                 policy_lr=0.001, value_lr=0.1):
    tf.reset_default_graph()
    policy_estimator = PolicyEstimator(env, lamb=lamb, learning_rate=policy_lr)
    value_estimator = ValueEstimator(env, learning_rate=value_lr)
    config = tf.ConfigProto(inter_op_parallelism_threads=1, intra_op_parallelism_threads=1)
    sess = tf.Session(config=config)
    sess.run(tf.global_variables_initializer())
    stats = []
    for i_episode in range(episodes):
        state = env.reset()
        reward_total = 0
        for t in itertools.count():
            action = policy_estimator.predict(state, sess)
            next_state, reward, done, _ = env.step(action)
            reward_total += reward

            if display:
                env.render()

            target = reward + gamma * value_estimator.predict(next_state, sess)
            td_error = target - value_estimator.predict(state, sess)

            policy_estimator.update(state, action, advantage=td_error, sess=sess)
            value_estimator.update(state, target, sess=sess)

            if done:
                break
            state = next_state
        stats.append(reward_total)
        if np.mean(stats[-100:]) > 90 and len(stats) >= 101:
            print(np.mean(stats[-100:]))
            print("Solved.")
        print("Episode: {}, reward: {}.".format(i_episode, reward_total))
    return np.mean(stats[-100:]), policy_estimator, sess


def controller_training(episodes=200):
    policy_lr, value_lr, lamb, gamma = [0.0001, 0.00046415888336127773,
                                        2.782559402207126e-05, 0.98999999999999999]
    loss, policy_estimator, sess = actor_critic(episodes=episodes, gamma=gamma,
                                                display=False, lamb=lamb,
                                                policy_lr=policy_lr, value_lr=value_lr)
    print(-loss)
    env.close()
    return policy_estimator, sess


pe, sess= controller_training(200)


from gym import spaces
def compute_traj(**kwargs):
    env.reset()
    if 'init_state' in kwargs:
        ob = kwargs['init_state']
        env.env.state = ob
    if 'goal_pos' in kwargs:
        gp = kwargs['goal_pos']
        env.env.goal_position = gp
    if 'max_speed' in kwargs:
        ms = kwargs['max_speed']
        env.env.max_speed = ms
        env.env.low_state = \
            np.array([env.env.min_position, - env.env.max_speed])
        env.env.high_state = \
            np.array([env.env.max_position, env.env.max_speed])
        env.env.observation_space = \
            spaces.Box(env.env.low_state, env.env.high_state)
    if 'power' in kwargs:
        pow = kwargs['power']
        env.env.power = pow
    if 'max_steps' in kwargs:
        max_steps = kwargs['max_steps']
    else:
        max_steps = np.inf

    iter_time = 0
    reward = 0
    done=False
    traj = [ob]
    while done==False:
        iter_time += 1
        action = pe.run_deterministic(ob, sess)
        ob, r, done, _ = env.step(np.array([action]))
        traj.append(ob)
        reward += r
        done = done or (iter_time >= max_steps)
        if done:
            break
    return traj, {'reward':reward, 'iter_time': iter_time}

def sut(x0, **kwargs):
    if 'max_steps' in kwargs:
        max_steps = kwargs['max_steps']
    else:
        max_steps = np.inf
    return compute_traj(max_steps=max_steps, init_state=x0[0:2],goal_pos=x0[2],
                        max_speed=x0[3], power=x0[4])

def sut_nv(x0, **kwargs):
    if 'max_steps' in kwargs:
        max_steps = kwargs['max_steps']
    else:
        max_steps = np.inf
    return compute_traj(max_steps=max_steps, init_state=np.array([x0[0], 0.]),goal_pos=x0[1],
                        max_speed=x0[2], power=x0[3])

from scipy.stats import chi2, norm

def cost_func(X):
    goal_rv = chi2(5, loc=0.3999999, scale=0.05/3.)
    speed_rv = chi2(5, scale=0.005/3.)
    power_rv = norm(0.0015, 0.00075)
    goal_pdf = goal_rv.pdf(X.T[2]) / goal_rv.pdf(0.45)
    speed_pdf = speed_rv.pdf(0.075- X.T[3]) / speed_rv.pdf(0.005)
    power_pdf = power_rv.pdf(X.T[4]) / power_rv.pdf(0.0015)
    goal_pdf.resize(len(goal_pdf), 1)
    speed_pdf.resize(len(speed_pdf), 1)
    power_pdf.resize(len(power_pdf), 1)
    return goal_pdf*speed_pdf*power_pdf
# Out:
# C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Episode: 0, reward: -25.741276920019427.
# Episode: 1, reward: -21.6020983672944.
# Episode: 2, reward: 91.08582590794201.
# Episode: 3, reward: -11.887040099810081.
# Episode: 4, reward: 93.51548484635943.
# Episode: 5, reward: 94.30033468738702.
# Episode: 6, reward: -8.916895695111306.
# Episode: 7, reward: -8.631035975622085.
# Episode: 8, reward: 93.8300265735056.
# Episode: 9, reward: 96.81963790602744.
# Episode: 10, reward: 93.78441428872114.
# Episode: 11, reward: -6.24062784612078.
# Episode: 12, reward: -5.825531727874687.
# Episode: 13, reward: -6.194743778088368.
# Episode: 14, reward: 94.82055962379367.
# Episode: 15, reward: -5.289917564498176.
# Episode: 16, reward: -3.9409522042606726.
# Episode: 17, reward: 96.21807167370574.
# Episode: 18, reward: -5.217970675734194.
# Episode: 19, reward: -3.959522720443153.
# Episode: 20, reward: -4.723931211584357.
# Episode: 21, reward: -3.6877282432070526.
# Episode: 22, reward: -4.745506837348373.
# Episode: 23, reward: -2.689039221580427.
# Episode: 24, reward: -3.2577509494930186.
# Episode: 25, reward: -3.0088815791156924.
# Episode: 26, reward: -2.2331616055104324.
# Episode: 27, reward: -0.4567324248780694.
# Episode: 28, reward: -0.7387956659167199.
# Episode: 29, reward: -0.4228590206565463.
# Episode: 30, reward: -0.3224087669976957.
# Episode: 31, reward: -0.38662034884347485.
# Episode: 32, reward: -0.34369169734356303.
# Episode: 33, reward: -0.10846517128289794.
# Episode: 34, reward: -0.08599839369763582.
# Episode: 35, reward: -0.08578125254331478.
# Episode: 36, reward: -0.05130972038874389.
# Episode: 37, reward: -0.036248995833715575.
# Episode: 38, reward: -0.1032284375867537.
# Episode: 39, reward: -0.030755764724395406.
# Episode: 40, reward: -0.2660963335149141.
# Episode: 41, reward: -0.05450146705886387.
# Episode: 42, reward: -0.26984930808108526.
# Episode: 43, reward: -0.02442444501845584.
# Episode: 44, reward: -0.01893064556072338.
# Episode: 45, reward: -0.03430957059342897.
# Episode: 46, reward: -0.08170641278678917.
# Episode: 47, reward: -0.02925522425269682.
# Episode: 48, reward: -0.0325561362750356.
# Episode: 49, reward: -0.018217244208253904.
# Episode: 50, reward: -0.024388263291336507.
# Episode: 51, reward: -0.28134943204852103.
# Episode: 52, reward: -0.03816103108734627.
# Episode: 53, reward: -0.2620827033207191.
# Episode: 54, reward: -0.026361883758997347.
# Episode: 55, reward: -0.02365532189035808.
# Episode: 56, reward: -0.036746249093673855.
# Episode: 57, reward: -0.22569867330125346.
# Episode: 58, reward: -0.01891380027275196.
# Episode: 59, reward: -0.014904176498168229.
# Episode: 60, reward: -0.05318566949326797.
# Episode: 61, reward: -0.06240191692061929.
# Episode: 62, reward: -0.051472327298185454.
# Episode: 63, reward: -0.018033614656720435.
# Episode: 64, reward: -0.04193837958830842.
# Episode: 65, reward: -0.020445307853458706.
# Episode: 66, reward: -0.06625949166330374.
# Episode: 67, reward: -0.048502254921511716.
# Episode: 68, reward: -0.02122409607465633.
# Episode: 69, reward: -0.11205331179969188.
# Episode: 70, reward: -0.050307383289096.
# Episode: 71, reward: -0.011681346177732614.
# Episode: 72, reward: -0.014016985834363683.
# Episode: 73, reward: -2.285404878371433.
# Episode: 74, reward: -0.08211127957870058.
# Episode: 75, reward: -0.03322328407717787.
# Episode: 76, reward: -0.014950079013376328.
# Episode: 77, reward: -0.3102166781062382.
# Episode: 78, reward: -0.014042103840301641.
# Episode: 79, reward: -0.055657393306511836.
# Episode: 80, reward: -0.1178965046926877.
# Episode: 81, reward: -0.018753218195693352.
# Episode: 82, reward: -0.017781081468448742.
# Episode: 83, reward: -0.023613073314791365.
# Episode: 84, reward: -0.10541386101998561.
# Episode: 85, reward: -0.016712291773191387.
# Episode: 86, reward: -0.01656101083283093.
# Episode: 87, reward: -0.048044017353712.
# Episode: 88, reward: -0.021182081449672565.
# Episode: 89, reward: -0.016774672234207408.
# Episode: 90, reward: -0.25646074256488616.
# Episode: 91, reward: -0.021260410994613337.
# Episode: 92, reward: -0.0659280334125811.
# Episode: 93, reward: -0.023482199818309436.
# Episode: 94, reward: -0.05819637798994261.
# Episode: 95, reward: -0.03895715254018833.
# Episode: 96, reward: -0.01491922686110761.
# Episode: 97, reward: -0.6047486020088927.
# Episode: 98, reward: -0.11114778390625732.
# Episode: 99, reward: -0.030132260818844545.
# Episode: 100, reward: -0.017168883951764084.
# Episode: 101, reward: -0.06838805189655577.
# Episode: 102, reward: -0.12308578538979717.
# Episode: 103, reward: -0.03257293142298272.
# Episode: 104, reward: -0.5212860288461286.
# Episode: 105, reward: -0.057964974858137015.
# Episode: 106, reward: -0.047692969226427746.
# Episode: 107, reward: -0.023042051057650264.
# Episode: 108, reward: -0.044023844489020386.
# Episode: 109, reward: -0.01940374304336803.
# Episode: 110, reward: -0.04278328247569593.
# Episode: 111, reward: -0.01701020366243814.
# Episode: 112, reward: -0.23120716813973993.
# Episode: 113, reward: -0.041157561706909714.
# Episode: 114, reward: -0.04547459460495714.
# Episode: 115, reward: -0.062303286782223924.
# Episode: 116, reward: -0.0338114432596212.
# Episode: 117, reward: -0.023044909449094434.
# Episode: 118, reward: -0.016429945589425975.
# Episode: 119, reward: -0.016606293938560432.
# Episode: 120, reward: -0.01676273768100907.
# Episode: 121, reward: -0.06644223390936507.
# Episode: 122, reward: -1.9387798734550699.
# Episode: 123, reward: -0.04077777976103044.
# Episode: 124, reward: -0.017620605345970368.
# Episode: 125, reward: -0.29575603584179827.
# Episode: 126, reward: -0.03738503252189746.
# Episode: 127, reward: -0.07068413819422496.
# Episode: 128, reward: -0.021841733391411256.
# Episode: 129, reward: -0.02624756443810022.
# Episode: 130, reward: -0.024121498413585758.
# Episode: 131, reward: -0.08340998638929976.
# Episode: 132, reward: -0.029458763433072792.
# Episode: 133, reward: -0.02047610342985848.
# Episode: 134, reward: -0.7103898714477436.
# Episode: 135, reward: -0.021318231653458454.
# Episode: 136, reward: -0.10121799172317199.
# Episode: 137, reward: -0.08821429373968866.
# Episode: 138, reward: -0.027562526781193752.
# Episode: 139, reward: -0.045495680859937083.
# Episode: 140, reward: -0.030347145727750144.
# Episode: 141, reward: -0.020367749557055056.
# Episode: 142, reward: -0.025402105025961918.
# Episode: 143, reward: -0.027378519046593563.
# Episode: 144, reward: -0.022061099325195965.
# Episode: 145, reward: -0.2583304574595169.
# Episode: 146, reward: -0.031073152226294577.
# Episode: 147, reward: -0.031117447307637883.
# Episode: 148, reward: -0.015381969861373324.
# Episode: 149, reward: -0.30396580687011704.
# Episode: 150, reward: -0.020977219726759495.
# Episode: 151, reward: -0.020562358879901394.
# Episode: 152, reward: -0.09682309856021265.
# Episode: 153, reward: -0.04116191661156695.
# Episode: 154, reward: -0.028539588840957385.
# Episode: 155, reward: -0.0270703048745562.
# Episode: 156, reward: -0.24213334646392434.
# Episode: 157, reward: -0.02483389501201146.
# Episode: 158, reward: -0.12438909183836246.
# Episode: 159, reward: -0.04965474447171579.
# Episode: 160, reward: -0.017669372889947403.
# Episode: 161, reward: -0.14411338204154128.
# Episode: 162, reward: -0.021986561347275054.
# Episode: 163, reward: -0.12751739222760922.
# Episode: 164, reward: -0.030219637831223868.
# Episode: 165, reward: -0.06349612017845967.
# Episode: 166, reward: -0.07659831521863333.
# Episode: 167, reward: -0.5861373149246023.
# Episode: 168, reward: -0.06671720922494549.
# Episode: 169, reward: -0.04184927770049017.
# Episode: 170, reward: -0.1318405737084742.
# Episode: 171, reward: -0.05911284711627734.
# Episode: 172, reward: -0.0723027292200814.
# Episode: 173, reward: -0.02100910183442075.
# Episode: 174, reward: -0.07670391812905869.
# Episode: 175, reward: -0.029872900365768795.
# Episode: 176, reward: -0.01858599516025327.
# Episode: 177, reward: -0.07672150147860016.
# Episode: 178, reward: -0.0364843190807847.
# Episode: 179, reward: -0.026284649589987292.
# Episode: 180, reward: -0.02727493296342389.
# Episode: 181, reward: -0.03480734109050289.
# Episode: 182, reward: -0.08127777720798884.
# Episode: 183, reward: -0.01321201266349287.
# Episode: 184, reward: -0.017822647079415492.
# Episode: 185, reward: -0.14773546914965324.
# Episode: 186, reward: -0.03952453900500438.
# Episode: 187, reward: -0.07341340339132202.
# Episode: 188, reward: -0.04022170056380942.
# Episode: 189, reward: -0.01740539276707487.
# Episode: 190, reward: -0.9932235120829116.
# Episode: 191, reward: -0.04018594282884173.
# Episode: 192, reward: -0.1391002963631395.
# Episode: 193, reward: -0.035323385494638766.
# Episode: 194, reward: -0.03692225264430807.
# Episode: 195, reward: -0.03651512407439682.
# Episode: 196, reward: -0.28431344834351036.
# Episode: 197, reward: -0.341191354826183.
# Episode: 198, reward: -0.15579907956962508.
# Episode: 199, reward: -0.30301215799553244.
# Cost 740.1256458759308 seconds.
# 0.1119349654326206

# %%
from adversarial_testing import pred_node, max_node, min_node, test_module
from adversarial_testing.utils import sample_from
rand_nums = [3188388221,
 1954593344,
 2154016205,
 3894811078,
 3493033583,
 3248332584,
 1304673443,
 3857496775,
 2668478815,
 278535713,
 1762150547,
 788841329,
 2525132954,
 677754898,
 754758634]

# Requirement 1: Find the initial configuration that minimizes the reward
# We need only one node for the reward. The reward is a smooth function
# given that the closed loop system is deterministic
bounds = [(-0.6, -0.4)] # Bounds on the position
bounds.append((-0.025, 0.025)) # Bounds on the velocity
bounds.append((0.4, 0.6)) # Bounds on the goal position
bounds.append((0.055, 0.075)) # Bounds on the max speed
bounds.append((0.0005, 0.0025)) # Bounds on the power magnitude


smooth_details_r1 = []
random_details_r1 = []

# This set assumes random sampling and checking
for r in rand_nums:
    np.random.seed(r)
    node0 = pred_node(f=lambda traj: traj[1]['reward'])
    TM = test_module(bounds=bounds, sut=lambda x0: sut(x0),
                     f_tree = node0, init_sample = 60,
                     optimize_restarts=5, exp_weight=2,
                     normalizer=True)
    TM.initialize()

    TM.run_BO(140)
    smooth_vals = np.array(TM.f_acqu.find_GP_func())
    smooth_details_r1.append([np.sum(smooth_vals < 75),
                              np.sum(smooth_vals < 0),
                              TM.smooth_min_x,
                              TM.smooth_min_val])




# With cost function
    np.random.seed(r)
    node0_cf = pred_node(f=lambda traj: traj[1]['reward'])
    TM_cf = test_module(bounds=bounds, sut=lambda x0: sut(x0),
                     f_tree = node0_cf, init_sample = 60,
                     optimize_restarts=5, exp_weight=10, cost_model=cost_func,
                     normalizer=True)
    TM_cf.initialize()

    TM_cf.run_BO(30)
    TM_cf.k = 5
    TM_cf.run_BO(40)
    TM_cf.k = 2
    TM_cf.run_BO(70)
    smooth_cf_vals = np.array(TM_cf.f_acqu.find_GP_func())
    smooth_details_r1.append([np.sum(smooth_cf_vals < 75),
                              np.sum(smooth_cf_vals < 0),
                              TM_cf.smooth_min_x,
                              TM_cf.smooth_min_val])
    np.random.seed(r)
    node0 = pred_node(f=lambda traj: traj[1]['reward'])
    TM = test_module(bounds=bounds, sut=lambda x0: sut(x0),
                     f_tree=node0, init_sample=70, with_smooth=False,
                     with_random=True,
                     optimize_restarts=5, exp_weight=10,
                     normalizer=True)
    TM.initialize()
    TM.run_BO(130)
    random_details_r1.append([np.sum(TM.random_Y < 75),
                              np.sum(TM.random_Y < 0),
                              TM.rand_min_x,
                              TM.rand_min_val])
    print(r, smooth_details_r1[-2],  smooth_details_r1[-1], random_details_r1[-1])
# Out:
# Running random sampling search for  1 rounds with  250000 samples in each round!
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = 85.13631573201857
# Optimization restart 2/5, f = -16.07160909598248
# Optimization restart 3/5, f = 49.621245636816724
#  C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:136: RuntimeWarning:overflow encountered in square
#  C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:invalid value encountered in add
# Optimization restart 4/5, f = -16.773806958374607
# Optimization restart 5/5, f = 51.07305474840533
# BO iteration: 0
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#  C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\paramz\transformations.py:111: RuntimeWarning:overflow encountered in expm1
# Optimization restart 1/5, f = -25.219976238272512
# Optimization restart 2/5, f = 86.55525781024349
# Optimization restart 3/5, f = -25.227559696031715
# Optimization restart 4/5, f = 86.55525425830345
# Optimization restart 5/5, f = 86.55525068361487
# BO iteration: 1
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -34.05012352738814
# Optimization restart 2/5, f = 87.97418917907515
#  C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:243: RuntimeWarning:invalid value encountered in true_divide
# Optimization restart 3/5, f = -4.0055544219308175
# Optimization restart 4/5, f = 84.65672998529924
# Optimization restart 5/5, f = 87.9741891966802
# BO iteration: 2
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -33.11125107209709
# Optimization restart 2/5, f = 89.39313603055567
# Optimization restart 3/5, f = -33.07150997627195
# Optimization restart 4/5, f = -33.192120405398214
# Optimization restart 5/5, f = 89.39312912081331
# BO iteration: 3
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -42.58411168773679
# Optimization restart 2/5, f = 90.81207519023855
# Optimization restart 3/5, f = 90.81206665235561
# Optimization restart 4/5, f = 37.67726609604886
# Optimization restart 5/5, f = -42.35098576272636
# BO iteration: 4
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -45.92777617878602
# Optimization restart 2/5, f = 92.2310072275256
# Optimization restart 3/5, f = -22.346581343093035
# Optimization restart 4/5, f = -16.11396831151187
# Optimization restart 5/5, f = -48.01381734994334
# BO iteration: 5
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -47.030278272757116
# Optimization restart 2/5, f = -49.8006698258567
# Optimization restart 3/5, f = -19.580989828083702
# Optimization restart 4/5, f = 91.18971077856853
# Optimization restart 5/5, f = -49.74016934481027
# BO iteration: 6
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -56.0232801122564
# Optimization restart 2/5, f = -56.02581298954803
# Optimization restart 3/5, f = -56.025813367915134
# Optimization restart 4/5, f = 27.231729723685
# Optimization restart 5/5, f = 22.212875384711182
# BO iteration: 7
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -59.04293140962585
# Optimization restart 2/5, f = 17.271846361954992
# Optimization restart 3/5, f = -59.08950258963836
# Optimization restart 4/5, f = 20.99055414446462
# Optimization restart 5/5, f = 23.123476333951153
# BO iteration: 8
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -67.6552427973355
# Optimization restart 2/5, f = -68.10176880232088
# Optimization restart 3/5, f = 26.537217958258374
# Optimization restart 4/5, f = -68.82747712176759
# Optimization restart 5/5, f = -37.71722261215051
# BO iteration: 9
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -76.22946936945235
# Optimization restart 2/5, f = -33.10487501280723
# Optimization restart 3/5, f = -75.04010071538869
# Optimization restart 4/5, f = -74.54994869681263
# Optimization restart 5/5, f = 24.768871314856106
# BO iteration: 10
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -83.27804311740083
# Optimization restart 2/5, f = 18.356119229271272
# Optimization restart 3/5, f = 18.112919750196685
# Optimization restart 4/5, f = 8.58949740238897
# Optimization restart 5/5, f = -34.72145081539476
# BO iteration: 11
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -90.49699172245867
# Optimization restart 2/5, f = -89.69702001563742
# Optimization restart 3/5, f = -90.5320143281162
# Optimization restart 4/5, f = 13.158978208344752
# Optimization restart 5/5, f = -89.11702696325933
# BO iteration: 12
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -97.71991459285545
# Optimization restart 2/5, f = 19.38907481193099
# Optimization restart 3/5, f = -96.0993694042233
# Optimization restart 4/5, f = 13.733485656247218
# Optimization restart 5/5, f = -95.41766462877973
# BO iteration: 13
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -105.10380251896564
# Optimization restart 2/5, f = -101.68033165113741
# Optimization restart 3/5, f = 12.443053699858217
# Optimization restart 4/5, f = 9.96260373125321
# Optimization restart 5/5, f = -100.29342519231562
# BO iteration: 14
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -113.0440240240942
# Optimization restart 2/5, f = -112.66883064497364
# Optimization restart 3/5, f = 10.484148859677077
# Optimization restart 4/5, f = 9.47258290886139
# Optimization restart 5/5, f = -112.62063454591481
# BO iteration: 15
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -120.99652827238208
# Optimization restart 2/5, f = 8.188245304201548
#  C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:437: RuntimeWarning:invalid value encountered in multiply
# Optimization restart 3/5, f = 80.15823268792685
# Optimization restart 4/5, f = 9.035262096450136
# Optimization restart 5/5, f = -116.52634967760514
# BO iteration: 16
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -128.79927455773444
# Optimization restart 2/5, f = 8.080699308680021
# Optimization restart 3/5, f = -125.72838956106744
# Optimization restart 4/5, f = -123.62898271031125
# Optimization restart 5/5, f = 4.986748243794912
# BO iteration: 17
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -136.6434790283861
# Optimization restart 2/5, f = -131.998663715773
# Optimization restart 3/5, f = -133.9155516241328
# Optimization restart 4/5, f = 2.760357097781492
# Optimization restart 5/5, f = 7.461151712633576
# BO iteration: 18
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -145.01571152596478
# Optimization restart 2/5, f = 14.91242951779233
# Optimization restart 3/5, f = -143.37230813209266
# Optimization restart 4/5, f = 6.765342313428411
# Optimization restart 5/5, f = 75.14186557166151
# BO iteration: 19
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -152.35829328709417
# Optimization restart 2/5, f = 19.638337609668582
# Optimization restart 3/5, f = 2.0208980557309992
# Optimization restart 4/5, f = -151.60206201409102
# Optimization restart 5/5, f = 5.344111243477794
# BO iteration: 20
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -160.03417102263347
# Optimization restart 2/5, f = 1.9026959419785925
# Optimization restart 3/5, f = -156.83627876397938
# Optimization restart 4/5, f = -154.22801924048935
# Optimization restart 5/5, f = -154.41935186822928
# BO iteration: 21
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -167.22090521788152
# Optimization restart 2/5, f = 1.307762007532789
# Optimization restart 3/5, f = 2.936667085244089
# Optimization restart 4/5, f = -165.38263826625854
# Optimization restart 5/5, f = 77.64011047639939
# BO iteration: 22
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -174.6099404465799
# Optimization restart 2/5, f = 2.8065970251016914
# Optimization restart 3/5, f = -2.3672775324996103
# Optimization restart 4/5, f = -170.18718067070722
# Optimization restart 5/5, f = -11.59185770347528
# BO iteration: 23
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -181.87956783561899
# Optimization restart 2/5, f = -180.2674162685519
# Optimization restart 3/5, f = -0.31316852833924713
# Optimization restart 4/5, f = -179.20766745194996
# Optimization restart 5/5, f = -176.61255521855193
# BO iteration: 24
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -189.53490836380453
# Optimization restart 2/5, f = 63.98212810062101
# Optimization restart 3/5, f = -186.50029665212858
# Optimization restart 4/5, f = -187.99430292190652
# Optimization restart 5/5, f = -185.9863906540699
# BO iteration: 25
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -197.5633657598927
# Optimization restart 2/5, f = -4.570854158118955
# Optimization restart 3/5, f = -194.91449511805178
# Optimization restart 4/5, f = -191.37808349110185
# Optimization restart 5/5, f = -196.2390879666758
# BO iteration: 26
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -205.3971065074871
# Optimization restart 2/5, f = -201.01823518092428
# Optimization restart 3/5, f = -201.45439965713857
# Optimization restart 4/5, f = 88.20224065502023
# Optimization restart 5/5, f = -7.550212734651119
# BO iteration: 27
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -213.7347154141242
# Optimization restart 2/5, f = -12.161445120818293
# Optimization restart 3/5, f = -210.93438722914465
# Optimization restart 4/5, f = -6.652270406247538
# Optimization restart 5/5, f = -210.77659418774368
# BO iteration: 28
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -220.61556685509848
# Optimization restart 2/5, f = -3.026085320903803
# Optimization restart 3/5, f = -217.56674333499797
# Optimization restart 4/5, f = -218.87290160734048
# Optimization restart 5/5, f = 0.46046643232212503
# BO iteration: 29
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -227.92349885118006
# Optimization restart 2/5, f = -226.31586119094993
# Optimization restart 3/5, f = -13.692024975198382
# Optimization restart 4/5, f = -226.94790672315565
# Optimization restart 5/5, f = -29.896801971287335
# BO iteration: 30
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -235.50518436210666
# Optimization restart 2/5, f = -17.896771336606662
# Optimization restart 3/5, f = -17.530449737126535
# Optimization restart 4/5, f = 71.87529823292809
# Optimization restart 5/5, f = -234.23756725508196
# BO iteration: 31
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -243.27773795695185
# Optimization restart 2/5, f = -17.3784302804033
# Optimization restart 3/5, f = -240.55445073197768
# Optimization restart 4/5, f = -240.29239270149162
# Optimization restart 5/5, f = 44.1663455080791
# BO iteration: 32
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -251.06057855321995
# Optimization restart 2/5, f = -19.58516587617084
# Optimization restart 3/5, f = -19.691937687662346
# Optimization restart 4/5, f = -18.594694444547798
# Optimization restart 5/5, f = -250.2861393898853
# BO iteration: 33
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -259.06998097987827
# Optimization restart 2/5, f = -24.066258060776125
# Optimization restart 3/5, f = -251.74600908768485
# Optimization restart 4/5, f = -25.898274173096812
# Optimization restart 5/5, f = -11.026930530340728
# BO iteration: 34
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -266.50452593199344
# Optimization restart 2/5, f = -23.715673258430414
# Optimization restart 3/5, f = -24.082983574760924
# Optimization restart 4/5, f = -262.8461087095152
# Optimization restart 5/5, f = -22.658560902652027
# BO iteration: 35
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -274.5232718148938
# Optimization restart 2/5, f = -268.0438609908382
# Optimization restart 3/5, f = -20.953466462711063
# Optimization restart 4/5, f = -267.7161004385149
# Optimization restart 5/5, f = -274.51890103161384
# BO iteration: 36
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -282.49883041124394
# Optimization restart 2/5, f = -281.5513478911415
# Optimization restart 3/5, f = -278.66139207836386
# Optimization restart 4/5, f = -11.193829113755946
# Optimization restart 5/5, f = -26.262481548531717
# BO iteration: 37
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -290.3612627536675
# Optimization restart 2/5, f = -289.1125092727819
# Optimization restart 3/5, f = -284.87803210686377
# Optimization restart 4/5, f = -287.47947642865336
# Optimization restart 5/5, f = -284.20537622313475
# BO iteration: 38
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -298.43448002352744
# Optimization restart 2/5, f = -294.3962459384834
# Optimization restart 3/5, f = -294.4366144200764
# Optimization restart 4/5, f = -291.9875653954821
# Optimization restart 5/5, f = -295.6102719992048
# BO iteration: 39
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -306.0829492340575
# Optimization restart 2/5, f = -304.1984146327877
# Optimization restart 3/5, f = -304.9575859409392
# Optimization restart 4/5, f = 56.13080163238277
# Optimization restart 5/5, f = -35.786854833520295
# BO iteration: 40
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -313.7118914212147
# Optimization restart 2/5, f = -312.0978895858909
# Optimization restart 3/5, f = -30.377000978896717
# Optimization restart 4/5, f = -306.3303842263256
# Optimization restart 5/5, f = -312.33494409697465
# BO iteration: 41
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -321.02097867097336
# Optimization restart 2/5, f = -39.39214389246202
# Optimization restart 3/5, f = -39.44366419589592
# Optimization restart 4/5, f = -39.240774023730786
# Optimization restart 5/5, f = -39.206915396657834
# BO iteration: 42
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -328.9640487117957
# Optimization restart 2/5, f = -324.3757293175296
# Optimization restart 3/5, f = -50.018228313944924
# Optimization restart 4/5, f = -325.1381011618608
# Optimization restart 5/5, f = -32.96121774261567
# BO iteration: 43
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -336.77498580682413
# Optimization restart 2/5, f = -52.50674295373222
# Optimization restart 3/5, f = -335.6904569684775
# Optimization restart 4/5, f = -45.01592499309002
# Optimization restart 5/5, f = -45.977206614793104
# BO iteration: 44
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -344.4068654240864
# Optimization restart 2/5, f = -47.74269201267197
# Optimization restart 3/5, f = -56.60002423397586
# Optimization restart 4/5, f = -339.56733273611303
# Optimization restart 5/5, f = -48.79057443813505
# BO iteration: 45
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -352.41170927553105
# Optimization restart 2/5, f = -346.1901595746091
# Optimization restart 3/5, f = -349.7425896099682
# Optimization restart 4/5, f = -350.5492863122474
# Optimization restart 5/5, f = -350.7277753389125
# BO iteration: 46
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -360.59643381619674
# Optimization restart 2/5, f = -359.13446698757156
# Optimization restart 3/5, f = -357.58652382337334
# Optimization restart 4/5, f = -52.21408250401283
# Optimization restart 5/5, f = -360.6126885036988
# BO iteration: 47
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -368.3892561354964
# Optimization restart 2/5, f = -362.9477450519082
# Optimization restart 3/5, f = -174.19667984335666
# Optimization restart 4/5, f = -66.37847231755026
# Optimization restart 5/5, f = -366.5050504593445
# BO iteration: 48
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -376.08572150834004
# Optimization restart 2/5, f = -56.99720027504076
# Optimization restart 3/5, f = -57.78003304466368
# Optimization restart 4/5, f = -370.95591937222514
# Optimization restart 5/5, f = -375.260071983645
# BO iteration: 49
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -383.78829122519863
# Optimization restart 2/5, f = -381.5085546613005
# Optimization restart 3/5, f = -380.9335536317928
# Optimization restart 4/5, f = -380.57222071733
# Optimization restart 5/5, f = -378.9500363780125
# BO iteration: 50
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -391.94099218079754
# Optimization restart 2/5, f = -390.46957678191103
# Optimization restart 3/5, f = -390.8432187096592
# Optimization restart 4/5, f = -51.70831447313971
# Optimization restart 5/5, f = -390.1730230652114
# BO iteration: 51
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -398.9901044572314
# Optimization restart 2/5, f = -73.83125325206754
# Optimization restart 3/5, f = -397.598648381814
# Optimization restart 4/5, f = -64.66035244294218
# Optimization restart 5/5, f = -396.8378184437446
# BO iteration: 52
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -406.75820268239204
# Optimization restart 2/5, f = -50.51595566540071
# Optimization restart 3/5, f = -68.80763442614374
# Optimization restart 4/5, f = -401.5233662415009
# Optimization restart 5/5, f = -404.94497590477175
# BO iteration: 53
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -414.46371796910046
# Optimization restart 2/5, f = -413.47528989625437
# Optimization restart 3/5, f = -71.55105231792231
# Optimization restart 4/5, f = -58.03489849809345
# Optimization restart 5/5, f = -412.39172304006905
# BO iteration: 54
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -422.45073593916436
# Optimization restart 2/5, f = -414.7836144840048
# Optimization restart 3/5, f = -415.8803936369877
# Optimization restart 4/5, f = -72.12963513247843
# Optimization restart 5/5, f = -420.0637013360971
# BO iteration: 55
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -430.34220932768756
# Optimization restart 2/5, f = -429.21377886994014
# Optimization restart 3/5, f = -427.83113007744555
# Optimization restart 4/5, f = -424.9488140896404
# Optimization restart 5/5, f = -427.9132284779266
# BO iteration: 56
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -438.34161898222476
# Optimization restart 2/5, f = -77.90631439317075
# Optimization restart 3/5, f = -435.1983764109619
# Optimization restart 4/5, f = -65.10321521517699
# Optimization restart 5/5, f = -437.03222615259494
# BO iteration: 57
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -446.1698046350027
# Optimization restart 2/5, f = -442.9085127062426
# Optimization restart 3/5, f = -67.6457423433144
# Optimization restart 4/5, f = -89.62330291730771
# Optimization restart 5/5, f = -444.19786547519334
# BO iteration: 58
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -453.8900661264797
# Optimization restart 2/5, f = -451.78586105275974
# Optimization restart 3/5, f = -81.49800250157004
# Optimization restart 4/5, f = -70.08442780753336
# Optimization restart 5/5, f = -451.71538869023647
# BO iteration: 59
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -461.7606686581032
# Optimization restart 2/5, f = -92.59236488874251
# Optimization restart 3/5, f = -460.8891498445222
# Optimization restart 4/5, f = -459.6262720450816
# Optimization restart 5/5, f = -460.66301432003957
# BO iteration: 60
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -469.7194453593233
# Optimization restart 2/5, f = -100.20611204064139
# Optimization restart 3/5, f = -465.8309539815411
# Optimization restart 4/5, f = -463.61891798090653
# Optimization restart 5/5, f = -468.8059286659819
# BO iteration: 61
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -477.70905647092354
# Optimization restart 2/5, f = -476.08667431743913
# Optimization restart 3/5, f = -89.61905100453943
# Optimization restart 4/5, f = -103.5454340365369
# Optimization restart 5/5, f = -474.3985201624554
# BO iteration: 62
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -485.80291870153536
# Optimization restart 2/5, f = -481.25863073744796
# Optimization restart 3/5, f = -485.79820396405665
# Optimization restart 4/5, f = -483.8106095311522
# Optimization restart 5/5, f = -106.26135558346941
# BO iteration: 63
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -493.64148895681984
# Optimization restart 2/5, f = -492.5984713429927
# Optimization restart 3/5, f = -492.6994202102595
# Optimization restart 4/5, f = -492.04608493959853
# Optimization restart 5/5, f = -110.11051598741115
# BO iteration: 64
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -501.0208433420312
# Optimization restart 2/5, f = -498.79164125663885
# Optimization restart 3/5, f = -112.31869437744243
# Optimization restart 4/5, f = -84.0437777673274
# Optimization restart 5/5, f = -499.2232968894622
# BO iteration: 65
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -508.4321011856257
# Optimization restart 2/5, f = -506.5659140689568
# Optimization restart 3/5, f = -507.0455806737955
# Optimization restart 4/5, f = -101.3306035621432
# Optimization restart 5/5, f = -506.77769505518495
# BO iteration: 66
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -514.8193487382661
# Optimization restart 2/5, f = -88.23224362139803
# Optimization restart 3/5, f = -103.55883651176417
# Optimization restart 4/5, f = -513.7946804965748
# Optimization restart 5/5, f = -514.0946978116816
# BO iteration: 67
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -522.6181810913633
# Optimization restart 2/5, f = -520.5666046286825
# Optimization restart 3/5, f = -518.6356593251625
# Optimization restart 4/5, f = -520.8586696683501
# Optimization restart 5/5, f = -515.9437882570757
# BO iteration: 68
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -530.4258544601145
# Optimization restart 2/5, f = -525.0384672664252
# Optimization restart 3/5, f = -524.6561053824081
# Optimization restart 4/5, f = -525.376650342115
# Optimization restart 5/5, f = -528.7819944970563
# BO iteration: 69
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -538.15296921733
# Optimization restart 2/5, f = -112.61254476535144
# Optimization restart 3/5, f = -535.1655471997173
# Optimization restart 4/5, f = -536.1212222345143
# Optimization restart 5/5, f = -177.57618815835906
# BO iteration: 70
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -545.4655700232438
# Optimization restart 2/5, f = -543.2670424091314
# Optimization restart 3/5, f = -545.1553300731955
# Optimization restart 4/5, f = -88.9731662052051
# Optimization restart 5/5, f = -544.901770032106
# BO iteration: 71
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -553.2377826034459
# Optimization restart 2/5, f = -553.1950100516095
# Optimization restart 3/5, f = -552.3470335579706
# Optimization restart 4/5, f = -553.2457558533904
# Optimization restart 5/5, f = -129.73033955017317
# BO iteration: 72
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -560.9735787564044
# Optimization restart 2/5, f = -558.2025770690476
# Optimization restart 3/5, f = -557.9875967851046
# Optimization restart 4/5, f = -559.7904530619629
# Optimization restart 5/5, f = -558.4512130021302
# BO iteration: 73
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -568.762297711882
# Optimization restart 2/5, f = -566.7517097933653
# Optimization restart 3/5, f = -567.2655340874744
# Optimization restart 4/5, f = -563.9879008291009
# Optimization restart 5/5, f = -568.5301210176938
# BO iteration: 74
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -576.686312723961
# Optimization restart 2/5, f = -575.536314164251
# Optimization restart 3/5, f = -575.2527329055952
# Optimization restart 4/5, f = -576.0602581643648
# Optimization restart 5/5, f = -574.2451785224125
# BO iteration: 75
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -584.4746286457886
# Optimization restart 2/5, f = -138.24987997682757
# Optimization restart 3/5, f = -135.39755755880276
# Optimization restart 4/5, f = -581.7277110150446
# Optimization restart 5/5, f = -127.28061106209283
# BO iteration: 76
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -592.4428656364033
# Optimization restart 2/5, f = -106.2961979410738
# Optimization restart 3/5, f = -133.90402803242355
# Optimization restart 4/5, f = -142.31196950533132
# Optimization restart 5/5, f = -588.2106524713487
# BO iteration: 77
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -600.4395503064089
# Optimization restart 2/5, f = -598.6879200286772
# Optimization restart 3/5, f = -128.5377341510975
# Optimization restart 4/5, f = -599.9003212090836
# Optimization restart 5/5, f = -594.1521603995
# BO iteration: 78
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -608.3488872184769
# Optimization restart 2/5, f = -604.3076234543017
# Optimization restart 3/5, f = -603.1022848417343
# Optimization restart 4/5, f = -603.1226185153589
# Optimization restart 5/5, f = -607.2891552198562
# BO iteration: 79
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -616.1715484516353
# Optimization restart 2/5, f = -614.6886411772798
# Optimization restart 3/5, f = -613.8135753192657
# Optimization restart 4/5, f = -613.6209152017966
# Optimization restart 5/5, f = -116.5951635736461
# BO iteration: 80
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -623.9055632798489
# Optimization restart 2/5, f = -202.9134422005813
# Optimization restart 3/5, f = -619.0513291513696
# Optimization restart 4/5, f = -143.71537611390474
# Optimization restart 5/5, f = -616.4668701964251
# BO iteration: 81
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -631.438027296412
# Optimization restart 2/5, f = -155.5944139180763
# Optimization restart 3/5, f = -628.5706387964506
# Optimization restart 4/5, f = -626.7789547902842
# Optimization restart 5/5, f = -155.95789184300236
# BO iteration: 82
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -639.1059595860065
# Optimization restart 2/5, f = -638.1116670686038
# Optimization restart 3/5, f = -637.0846031475702
# Optimization restart 4/5, f = -637.631587373798
# Optimization restart 5/5, f = -633.8966077234542
# BO iteration: 83
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -646.4945307898648
# Optimization restart 2/5, f = -643.8801638640882
# Optimization restart 3/5, f = -646.2554934519769
# Optimization restart 4/5, f = -644.5722542401458
# Optimization restart 5/5, f = -644.2799726023295
# BO iteration: 84
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -653.6813417490887
# Optimization restart 2/5, f = -652.2314647577012
# Optimization restart 3/5, f = -141.45577349350387
# Optimization restart 4/5, f = -648.6001431936029
# Optimization restart 5/5, f = -646.7520038904315
# BO iteration: 85
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -661.637942032617
# Optimization restart 2/5, f = -152.81379277803268
# Optimization restart 3/5, f = -168.16381378694103
# Optimization restart 4/5, f = -147.91970904968002
# Optimization restart 5/5, f = -436.41695116591086
# BO iteration: 86
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -667.0254351295736
# Optimization restart 2/5, f = -665.2275613937229
# Optimization restart 3/5, f = -664.1867573029347
# Optimization restart 4/5, f = -665.2778185668838
# Optimization restart 5/5, f = -664.7795539049216
# BO iteration: 87
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -674.8072189074237
# Optimization restart 2/5, f = -667.8685193078762
# Optimization restart 3/5, f = -671.2978336382631
# Optimization restart 4/5, f = -153.66567641023659
# Optimization restart 5/5, f = -670.1642610020864
# BO iteration: 88
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -682.7036609752505
# Optimization restart 2/5, f = -158.9149025282642
# Optimization restart 3/5, f = -680.9533582938597
# Optimization restart 4/5, f = -160.89448787398032
# Optimization restart 5/5, f = -167.40816437523623
# BO iteration: 89
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -690.2494660818604
# Optimization restart 2/5, f = -685.4857920862053
# Optimization restart 3/5, f = -176.60885113086692
# Optimization restart 4/5, f = -689.75451049309
# Optimization restart 5/5, f = -689.5329833248795
# BO iteration: 90
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -697.7246431225354
# Optimization restart 2/5, f = -695.4528282628123
# Optimization restart 3/5, f = -695.0702839702196
# Optimization restart 4/5, f = -691.7574323006501
# Optimization restart 5/5, f = -146.96063927630652
# BO iteration: 91
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -705.5982868392133
# Optimization restart 2/5, f = -697.6842137177265
# Optimization restart 3/5, f = -148.9832612794172
# Optimization restart 4/5, f = -704.6310453675429
# Optimization restart 5/5, f = -704.7164122691095
# BO iteration: 92
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -713.4663526249832
# Optimization restart 2/5, f = -185.5638097528242
# Optimization restart 3/5, f = -711.5745728133684
# Optimization restart 4/5, f = -712.1804306981155
# Optimization restart 5/5, f = -711.6212941797119
# BO iteration: 93
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -721.3275134198558
# Optimization restart 2/5, f = -169.97451116577884
# Optimization restart 3/5, f = -719.0420582673755
# Optimization restart 4/5, f = -719.4827466801516
# Optimization restart 5/5, f = -721.3352036632313
# BO iteration: 94
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -729.0151656387948
# Optimization restart 2/5, f = -727.4441522633241
# Optimization restart 3/5, f = -724.7992463239823
# Optimization restart 4/5, f = -725.898868432884
# Optimization restart 5/5, f = -728.9444221955291
# BO iteration: 95
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -736.6989719314308
# Optimization restart 2/5, f = -734.4409559361764
# Optimization restart 3/5, f = -734.5440796793317
# Optimization restart 4/5, f = -730.6905908258924
# Optimization restart 5/5, f = -730.595267505719
# BO iteration: 96
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -744.4260231399986
# Optimization restart 2/5, f = -176.04897168765083
# Optimization restart 3/5, f = -739.663850720983
# Optimization restart 4/5, f = -743.6418253856096
# Optimization restart 5/5, f = -736.4509169436823
# BO iteration: 97
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -752.1435042710496
# Optimization restart 2/5, f = -750.7892863549594
# Optimization restart 3/5, f = -751.4588417616238
# Optimization restart 4/5, f = -745.9196998148122
# Optimization restart 5/5, f = -746.7274701361065
# BO iteration: 98
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -760.0896821687095
# Optimization restart 2/5, f = -202.45140128387968
#  C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in multiply
#  C:\Users\gangop_b\AppData\Local\Continuum\anaconda3\lib\site-packages\GPy\kern\src\stationary.py:137: RuntimeWarning:overflow encountered in add
# Optimization restart 3/5, f = -754.6997382565363
# Optimization restart 4/5, f = -756.0403275704867
# Optimization restart 5/5, f = -758.4325153733483
# BO iteration: 99
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -767.9169180030947
# Optimization restart 2/5, f = -180.29520030242753
# Optimization restart 3/5, f = -760.8388104654999
# Optimization restart 4/5, f = -760.8944168488241
# Optimization restart 5/5, f = -766.3967222672278
# BO iteration: 100
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -775.8045857689965
# Optimization restart 2/5, f = -775.7880534270623
# Optimization restart 3/5, f = -775.7282723153652
# Optimization restart 4/5, f = -773.9789884730626
# Optimization restart 5/5, f = -204.17622718033405
# BO iteration: 101
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -783.1243849966706
# Optimization restart 2/5, f = -782.3366863500429
# Optimization restart 3/5, f = -776.8502615637688
# Optimization restart 4/5, f = -780.9148561485079
# Optimization restart 5/5, f = -783.0020788541932
# BO iteration: 102
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -789.7350170039573
# Optimization restart 2/5, f = -782.8529594125802
# Optimization restart 3/5, f = -312.2410725680674
# Optimization restart 4/5, f = -782.23090673069
# Optimization restart 5/5, f = -786.1044912178561
# BO iteration: 103
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -796.7362432831709
# Optimization restart 2/5, f = -794.751623852931
# Optimization restart 3/5, f = -790.5272995301186
# Optimization restart 4/5, f = -795.2322893051446
# Optimization restart 5/5, f = -795.6077955088125
# BO iteration: 104
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -804.5549000812921
# Optimization restart 2/5, f = -797.7441590192801
# Optimization restart 3/5, f = -798.0317628474189
# Optimization restart 4/5, f = -193.26650627666032
# Optimization restart 5/5, f = -195.46499410865886
# BO iteration: 105
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -812.2945262656473
# Optimization restart 2/5, f = -810.3609734466831
# Optimization restart 3/5, f = -805.9623868079225
# Optimization restart 4/5, f = -152.69219251847295
# Optimization restart 5/5, f = -211.52325717774877
# BO iteration: 106
# Iteration number:  0
# ...
# Optimization restart 1/5, f = -156.64721277134407
# Optimization restart 2/5, f = -156.01548011885066
# Optimization restart 3/5, f = -156.58425452649203
# Optimization restart 4/5, f = 57.29750879411925
# Optimization restart 5/5, f = -156.60969129197133
# BO iteration: 17
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -161.89567283222624
# Optimization restart 2/5, f = 57.546086065592746
# Optimization restart 3/5, f = 60.41581537229287
# Optimization restart 4/5, f = 58.7177900017735
# Optimization restart 5/5, f = 83.28998208979328
# BO iteration: 18
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -167.62668753908918
# Optimization restart 2/5, f = -167.6118208185116
# Optimization restart 3/5, f = 112.64826456338088
# Optimization restart 4/5, f = -167.627449752015
# Optimization restart 5/5, f = -167.6034945627166
# BO iteration: 19
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -171.3809911661766
# Optimization restart 2/5, f = -171.38024306065307
# Optimization restart 3/5, f = -171.32067837234803
# Optimization restart 4/5, f = 57.96600787859533
# Optimization restart 5/5, f = -171.31608426078486
# BO iteration: 20
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -176.1481655648708
# Optimization restart 2/5, f = -176.027087576412
# Optimization restart 3/5, f = -176.08086091036887
# Optimization restart 4/5, f = -176.1289941121485
# Optimization restart 5/5, f = -176.12957328258062
# BO iteration: 21
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -180.2237713653407
# Optimization restart 2/5, f = 50.683768882422385
# Optimization restart 3/5, f = 83.64455301921797
# Optimization restart 4/5, f = 54.952399656525806
# Optimization restart 5/5, f = -180.1161149721859
# BO iteration: 22
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -186.35222077692876
# Optimization restart 2/5, f = -186.31375686249584
# Optimization restart 3/5, f = 110.52635345757645
# Optimization restart 4/5, f = 68.64785567885271
# Optimization restart 5/5, f = -186.27171816231495
# BO iteration: 23
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -191.71767255572666
# Optimization restart 2/5, f = 61.49680757625558
# Optimization restart 3/5, f = -191.4345595444405
# Optimization restart 4/5, f = 51.50442324510456
# Optimization restart 5/5, f = 58.41215281497968
# BO iteration: 24
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -198.28672175338875
# Optimization restart 2/5, f = -198.12143304564813
# Optimization restart 3/5, f = -198.25610810461245
# Optimization restart 4/5, f = -198.21666956958205
# Optimization restart 5/5, f = 52.16474447995763
# BO iteration: 25
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -203.83069927618394
# Optimization restart 2/5, f = 52.8075123328639
# Optimization restart 3/5, f = -203.42483973860067
# Optimization restart 4/5, f = 119.7062731150946
# Optimization restart 5/5, f = 48.96094273459296
# BO iteration: 26
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -208.804574654389
# Optimization restart 2/5, f = -208.60104126016597
# Optimization restart 3/5, f = 116.48297899613107
# Optimization restart 4/5, f = -208.5932071081822
# Optimization restart 5/5, f = 33.97633412443152
# BO iteration: 27
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -213.80506174812615
# Optimization restart 2/5, f = -97.48745956238255
# Optimization restart 3/5, f = -213.57112325756745
# Optimization restart 4/5, f = -213.78424636216204
# Optimization restart 5/5, f = 56.364977782834146
# BO iteration: 28
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -220.34444422276314
# Optimization restart 2/5, f = -220.33364196331928
# Optimization restart 3/5, f = -220.31455576522376
# Optimization restart 4/5, f = -220.01717887292648
# Optimization restart 5/5, f = -220.01462442102354
# BO iteration: 29
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -225.31537298448603
# Optimization restart 2/5, f = 61.092246045414754
# Optimization restart 3/5, f = -225.28950000033961
# Optimization restart 4/5, f = -224.92798813011984
# Optimization restart 5/5, f = 53.6847277769914
# BO iteration: 30
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -229.04847013035112
# Optimization restart 2/5, f = -228.9846890753025
# Optimization restart 3/5, f = 60.41830205927594
# Optimization restart 4/5, f = -228.29389233661152
# Optimization restart 5/5, f = 58.370806850000456
# BO iteration: 31
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -232.70755999127232
# Optimization restart 2/5, f = 57.217486198712194
# Optimization restart 3/5, f = 74.00208115230751
# Optimization restart 4/5, f = 59.14315581718305
# Optimization restart 5/5, f = -232.67679094917816
# BO iteration: 32
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -238.07795551259701
# Optimization restart 2/5, f = 59.57902188762972
# Optimization restart 3/5, f = -237.9973349565526
# Optimization restart 4/5, f = 67.15362201193513
# Optimization restart 5/5, f = 52.20326257551704
# BO iteration: 33
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -243.65714362361126
# Optimization restart 2/5, f = -243.28938463731544
# Optimization restart 3/5, f = -243.21440305707415
# Optimization restart 4/5, f = 59.90223071666139
# Optimization restart 5/5, f = 58.3135024378298
# BO iteration: 34
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -248.95154180108602
# Optimization restart 2/5, f = 58.18927004467443
# Optimization restart 3/5, f = 96.77835613209558
# Optimization restart 4/5, f = -248.11170596653318
# Optimization restart 5/5, f = 57.82193147534854
# BO iteration: 35
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -253.7102343982969
# Optimization restart 2/5, f = -253.71571423587946
# Optimization restart 3/5, f = -253.631463561379
# Optimization restart 4/5, f = -253.56325676026322
# Optimization restart 5/5, f = -111.40669042831335
# BO iteration: 36
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -258.58424262696195
# Optimization restart 2/5, f = -258.5090530544932
# Optimization restart 3/5, f = -258.571575251618
# Optimization restart 4/5, f = -258.5268353894541
# Optimization restart 5/5, f = -258.3498951191778
# BO iteration: 37
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -263.91679161703576
# Optimization restart 2/5, f = -263.9298838599093
# Optimization restart 3/5, f = -263.8648672389354
# Optimization restart 4/5, f = 56.41020329723257
# Optimization restart 5/5, f = 59.52897622514041
# BO iteration: 38
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -260.7334631560095
# Optimization restart 2/5, f = 78.50447600598191
# Optimization restart 3/5, f = -260.157176656046
# Optimization restart 4/5, f = 52.68435058461061
# Optimization restart 5/5, f = -260.4613185133525
# BO iteration: 39
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -267.075992131633
# Optimization restart 2/5, f = 99.2948916939722
# Optimization restart 3/5, f = -267.03237367233766
# Optimization restart 4/5, f = -266.7518047564604
# Optimization restart 5/5, f = 58.781040162865246
# BO iteration: 0
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -269.0251482866979
# Optimization restart 2/5, f = 62.15504034116213
# Optimization restart 3/5, f = -268.64867630293634
# Optimization restart 4/5, f = -268.8440368707216
# Optimization restart 5/5, f = 57.774079651678015
# BO iteration: 1
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -274.3522365660801
# Optimization restart 2/5, f = 78.64005956589547
# Optimization restart 3/5, f = 54.495188367709034
# Optimization restart 4/5, f = 56.052165477911416
# Optimization restart 5/5, f = 57.88405239921372
# BO iteration: 2
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -279.9961221961138
# Optimization restart 2/5, f = 55.408884736098045
# Optimization restart 3/5, f = 62.16036056790383
# Optimization restart 4/5, f = -279.9935611763658
# Optimization restart 5/5, f = 84.77033497397265
# BO iteration: 3
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -284.62439179475075
# Optimization restart 2/5, f = -283.58545534903726
# Optimization restart 3/5, f = -284.6273470097623
# Optimization restart 4/5, f = 57.1512702180096
# Optimization restart 5/5, f = -284.5576045283737
# BO iteration: 4
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -290.7776666741038
# Optimization restart 2/5, f = 66.52495394660637
# Optimization restart 3/5, f = -290.7776101649774
# Optimization restart 4/5, f = 55.90561802596212
# Optimization restart 5/5, f = 58.97519426917327
# BO iteration: 5
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -295.2033549814886
# Optimization restart 2/5, f = -295.0722118165712
# Optimization restart 3/5, f = 61.718540917832655
# Optimization restart 4/5, f = -294.6902345886946
# Optimization restart 5/5, f = -295.05821748618047
# BO iteration: 6
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -299.93768444186355
# Optimization restart 2/5, f = -299.60116542268554
# Optimization restart 3/5, f = -299.8984067646316
# Optimization restart 4/5, f = -299.9564381006545
# Optimization restart 5/5, f = 58.98039588356836
# BO iteration: 7
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -305.112167684424
# Optimization restart 2/5, f = 57.49555886278878
# Optimization restart 3/5, f = -304.6255481252747
# Optimization restart 4/5, f = -304.9966451722042
# Optimization restart 5/5, f = -305.0561271701353
# BO iteration: 8
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -310.85199886903894
# Optimization restart 2/5, f = 62.9459408164271
# Optimization restart 3/5, f = 58.694346193054926
# Optimization restart 4/5, f = -310.8439955072523
# Optimization restart 5/5, f = 59.22408321991257
# BO iteration: 9
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -316.42139053807585
# Optimization restart 2/5, f = 53.152580807539735
# Optimization restart 3/5, f = -316.2128404859974
# Optimization restart 4/5, f = -316.33639910101726
# Optimization restart 5/5, f = -316.44075548203296
# BO iteration: 10
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -322.7305442922003
# Optimization restart 2/5, f = -322.7049100113376
# Optimization restart 3/5, f = -322.64419252056524
# Optimization restart 4/5, f = 32.03570013938892
# Optimization restart 5/5, f = -322.5296306858912
# BO iteration: 11
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -327.8447902433721
# Optimization restart 2/5, f = -327.04978873682614
# Optimization restart 3/5, f = 62.95384920042326
# Optimization restart 4/5, f = -327.5279013754494
# Optimization restart 5/5, f = 57.72468288682742
# BO iteration: 12
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -333.1571193410992
# Optimization restart 2/5, f = 59.93069807677678
# Optimization restart 3/5, f = 59.91671203536562
# Optimization restart 4/5, f = 55.50727772224593
# Optimization restart 5/5, f = 54.53671652903347
# BO iteration: 13
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -336.5652775877344
# Optimization restart 2/5, f = -335.9708528026632
# Optimization restart 3/5, f = -335.9047785530329
# Optimization restart 4/5, f = 60.39569181931661
# Optimization restart 5/5, f = -336.41711390829215
# BO iteration: 14
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -342.93588876441675
# Optimization restart 2/5, f = 60.30635761738439
# Optimization restart 3/5, f = 61.03293956935204
# Optimization restart 4/5, f = 64.8077188548955
# Optimization restart 5/5, f = -342.89753840360447
# BO iteration: 15
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -347.97553267771104
# Optimization restart 2/5, f = -347.6368106079493
# Optimization restart 3/5, f = -346.90581720079456
# Optimization restart 4/5, f = -347.6051340043015
# Optimization restart 5/5, f = -347.7455676347661
# BO iteration: 16
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -353.54840505678226
# Optimization restart 2/5, f = -352.93821638635535
# Optimization restart 3/5, f = -353.4857866851387
# Optimization restart 4/5, f = -353.28429749766536
# Optimization restart 5/5, f = -353.4410401111828
# BO iteration: 17
# Iteration number:  0
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Optimization restart 1/5, f = -359.2956761055702
# Optimization restart 2/5, f = -358.7639860644642
# Optimization restart 3/5, f = -359.2157188630393
# Optimization restart 4/5, f = -359.01432472623605
# Optimization restart 5/5, f = -358.75517042626694
# BO iteration: 18
# Iteration number:  0
